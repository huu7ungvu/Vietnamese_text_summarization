# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekjoshi565/textrank_text_summarization/blob/master/TestRank_Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt') # one time execution
import re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# %%capture

# !wget 'https://github.com/ThanhChinhBK/vietnews/archive/master.zip'
# !unzip 'master.zip'

# %%
# %%capture
# Install the vncorenlp python wrapper
# !pip install vncorenlp
# Download VnCoreNLP-1.1.1.jar & its word segmentation component (i.e. RDRSegmenter) 
# !mkdir -p vncorenlp/models/wordsegmenter
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/VnCoreNLP-1.1.1.jar
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/vi-vocab
# !wget https://raw.githubusercontent.com/vncorenlp/VnCoreNLP/master/models/wordsegmenter/wordsegmenter.rdr
# !mv VnCoreNLP-1.1.1.jar vncorenlp/ 
# !mv vi-vocab vncorenlp/models/wordsegmenter/
# !mv wordsegmenter.rdr vncorenlp/models/wordsegmenter/
# !pip install datasets==1.0.2

# %%
import glob
import pandas as pd
import concurrent.futures
from datasets import *

# %%
def listPaths(path):
  pathfiles = list()
  for pathfile in glob.glob(path):
    pathfiles.append(pathfile)
  return pathfiles

train_paths = listPaths('/content/vietnews-master/data/train_tokenized/*')
val_paths = listPaths('/content/vietnews-master/data/val_tokenized/*')
test_paths = listPaths('/content/vietnews-master/data/test_tokenized/*')

# %%
def read_content(pathfile):
  """
  Input: Path of txt file
  Output: A dictionary has keys 'original' and 'summary'
  """
  with open(pathfile) as f:
    rows  = f.readlines()
    original = ' '.join(''.join(rows[4:]).split('\n'))
    summary = ' '.join(rows[2].split('\n'))
          
  return {'file' : pathfile,
          'original': original, 
          'summary': summary}

# %%
read_content(train_paths[0])
# Out:
# {'file': '/content/vietnews-master/data/train_tokenized/065352.txt.seg',
#  'original': 'Chủ thẻ VinID khi mua_sắm và sử_dụng dịch_vụ có tích điểm trên toàn hệ_thống của Vingroup sẽ được tham_gia các chương_trình siêu khuyến_mại mỗi ngày và cơ_hội bốc_thăm trúng hàng ngàn giải_thưởng giá_trị . “ 365 NGÀY VUI ” là chương_trình khuyến_mại ưu_việt đặc_biệt áp_dụng từ 1.4.2018 dành riêng cho các chủ thẻ VinID trên cả nước . Theo đó , mỗi tháng VinID sẽ dành hơn4 tỷ khuyến_mại trực_tiếp vào các sản_phẩm dịch_vụ trong hệ_sinh_thái của tập_đoàn và 4 tỷ cho các chương_trình bốc_thăm với hàng ngàn giải_thưởng giá_trị . Các chương_trình khuyến_mãi và bốc_thăm được thiết_kế linh_hoạt công_bố vào cuối mỗi tháng trước đó nhằm mang lại nhiều niềm_vui và bất_ngờ dành cho các khách_hàng thân_thiết . Mở_đầu chuỗi “ 365 ngày vui ” là chương_trình khuyến_mại đặc_biệt của tháng 4 với mỗi tuần 1 chủ_đề ưu_đãi : Nghỉ_dưỡng Vinpearl ( tuần 1 ) , sản_phẩm điện_máy VinPro ( tuần 2 ) , Học_đường Vinschool và Y_tế Vinmec ( tuần 3 ) và tuần cuối tập_trung cho khối bán_lẻ tiêu_dùng siêu_thị VinMart & cửa_hàng tiện_lợi VinMart + . Đặc_biệt , chương_trình bốc_thăm trúng thưởng của tháng 4.2018 sẽ có riêng ngày “ Thứ_Sáu may_mắn ” với cơ_hội trúng 6.666 giải_thưởng tổng trị_giá lên tới 1 tỷ đồng / tuần . Chương_trình áp_dụng cho các chủ thẻ VinID có phát_sinh giao_dịch mua_sắm trong tuần với tổng hoá_đơn trị_giá từ 500.000 đồng / tuần trở lên và mã_số tham_gia dự_thưởng chính là 16 số ghi trên thẻ VinID . Hàng chục ngàn giải_thưởng chương_trình quay số “ Thứ_Sáu may_mắn ” đến từ các sản_phẩm dịch_vụ 5 sao của tập_đoàn Vingroup trong tháng 4 sẽ mang tới cơ_hội trúng thưởng lớn nhất từ trước tới nay dành cho mọi khách_hàng thân_thiết . Trong đó , giải đặc_biệt của tuần đầu_tiên là trải nghiệm kỳ nghỉ Tổng_thống 3 ngày 2 đêm ở Villa Tổng_thống Presidental_Suite_Villa tại Vinpearl_Phú_Quốc_Resort trị_giá lên tới 200 triệu đồng . Khách trúng giải đặc_biệt tuần thứ 2 sẽ được nhận bộ sản_phẩm công_nghệ từ hệ_thống VinPro trị_giá lên tới hơn 100 triệu đồng . Trong tuần ưu_đãi học_đường và y_tế , khách_hàng sẽ có cơ_hội sở_hữu Gói_Bảo_Hiểm_Sức_Khoẻ Vinmec_Ruby - Bảo_Việt dành cho 3 người trong gia_đình_trị giá 100 triệu . Giải đặc_biệt của chương_trình khuyến_mại tuần thứ 4 đến từ hệ_thống VinMart và VinMart + là Bộ phiếu mua hàng trị_giá 100 triệu đồng dành cho người may_mắn nhất . Khách mua_sắm theo chủ_đề tuần khuyến_mại trong tháng 4 cũng sẽ nhận được ưu_đãi giảm_giá đặc_biệt và quà tặng trực_tiếp giá_trị từ thương_hiệu tài_trợ và đối_tác liên_quan . Bên cạnh mong_muốn mang lại cho khách_hàng nhiều niềm_vui , sự may_mắn bất_ngờ , chương_trình “ 365 ngày vui ” với tổng giá_trị khuyến_mại và quà tặng mỗi tháng lên tới 8 tỷ đồng còn thể_hiện sự tri_ân của Vingroup tới những khách_hàng thân_thiết trên cả nước đã luôn ủng_hộ và đồng_hành cùng sự phát_triển của tập_đoàn .  6.666 giải_thưởng mỗi tuần trong chương_trình “ 365 Ngày vui ” - Tháng_Tư . Chủ thẻ VinID có cơ_hội trải nghiệm kỳ nghỉ Tổng_thống ở Villa Tổng_thống Presidental_Suite_Villa tại Vinpearl_Phú_Quốc_Resort trị_giá lên tới 200 triệu đồng . Vinschool tặng balo & mũ đồng_phục cho chủ thẻ VinID khi đăng_ký cho con_em tham_gia khoá học Hè – 2018 . “ 365 Ngày vui ” mang lại cho khách_hàng cơ_hội sở_hữu hàng nghìn sản_phẩm với giá ưu_đãi ',
#  'summary': 'Từ 1/4/2018 , Vingroup công_bố triển_khai chương_trình tri ân khách_hàng mang tên “ 365 ngày vui ” với tổng giá_trị lên tới 100 tỷ . '}

# %%
def get_dataframe(pathfiles):
  with concurrent.futures.ProcessPoolExecutor() as executor:
    data = executor.map(read_content, pathfiles)
  
  # Make blank dataframe
  data_df = list()
  for d in data:
    data_df.append(d)
  data_df = pd.DataFrame(data_df)
  data_df.dropna(inplace = True)
  data_df = data_df.sample(frac=1).reset_index(drop=True)

  return data_df

# %%
train_df = get_dataframe(train_paths)

# %%
test_df = get_dataframe(test_paths)
val_df = get_dataframe(val_paths)

# %%
train_df.head(2)
# Out:
#                                                 file  ...                                            summary
# 0  /content/vietnews-master/data/train_tokenized/...  ...  Lô hàng trị_giá hơn 100 triệu đồng từ Singapor...
# 1  /content/vietnews-master/data/train_tokenized/...  ...  Chủ_nhân ca_khúc " Gangnam_Style " thừa_nhận t...
#
# [2 rows x 3 columns]

# %% [markdown]
# ## word to vec

# %%
! unzip glove*.zip
# Out:
# Archive:  glove.6B.zip
#   inflating: glove.6B.50d.txt
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt

# %%
# Extract word vectors
word_embeddings = {}
f = open('glove.6B.100d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    word_embeddings[word] = coefs
f.close()

# %%
sentence_vectors = []
for i in clean_sentences:
  if len(i) != 0:
    v = sum([word_embeddings.get(w, np.zeros((100,))) for w in i.split()])/(len(i.split())+0.001)
  else:
    v = np.zeros((100,))
  sentence_vectors.append(v)

# %%
len(sentence_vectors)
# Out:
# 16

# %% [markdown]
# ## word to vec (vietnamese)

# %%
# !pip install -q pyvi
# Out:
#      |████████████████████████████████| 8.5 MB 4.6 MB/s
#      |████████████████████████████████| 743 kB 29.3 MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read embedding
word_dict = []
embeddings_index = {}
embedding_dim = 300
max_feature = len(embeddings_index) + 2

f = open('/content/drive/MyDrive/nam3/course/nlp/W2V_C2V_ner.vec')
for line in f:
    values = line.split(' ')
    word = values[0] 
    word_dict.append(word)
    try:
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    except Exception as e:
        pass
f.close()

print('Embedding data loaded')
# Out:
# Embedding data loaded

# %% [markdown]
# The next step is to find similarities among the sentences. We will use cosine similarity to find similarity between a pair of sentences. Let's create an empty similarity matrix for this task and populate it with cosine similarities of the sentences.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
import networkx as nx

# nx_graph = nx.from_numpy_array(sim_mat)
# scores = nx.pagerank(nx_graph, max_iter=100)

# %%
# !pip install -q rouge-score

# %% [markdown]
# ## Text rank in test set

# %%
import networkx as nx
df_sumary = []
# split the the text in the articles into sentences
sentences = []

for s in test_df.original:
  sentences.append(sent_tokenize(s))  
for i in range(len(test_df.original)):
  try:
    sentences_index = sentences[i]

    # remove punctuations, numbers and special characters
    clean_sentences = pd.Series(sentences_index).str.replace("[^\w\s]", " ")
    for i in range(len(clean_sentences)):
      clean_sentences[i] = " ".join(clean_sentences[i].split())
    clean_sentences = clean_sentences.replace('', np.nan).dropna()


    sentence_vectors = []
    for i in clean_sentences:
      if len(i) != 0:
        v = sum([embeddings_index.get(w, np.zeros((300,))) for w in i.split()])/(len(i.split())+0.001)
      else:
        v = np.zeros((300,))
      sentence_vectors.append(v)

    len(sentence_vectors)

    # similarity matrix
    sim_mat = np.zeros([len(sentences_index), len(sentences_index)])
    for i in range(len(sentence_vectors)):
      for j in range(len(sentence_vectors)):
        if i != j:
          sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,300), sentence_vectors[j].reshape(1,300))[0,0]



    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph) # tính score

    ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences_index)), reverse=True)

    # Specify number of sentences to form the summary
    sn = 3

    # Generate summary
    list_result = []
    str1 = []
    for i in range(sn):
      list_result.append(ranked_sentences[i][1])
      str1 = ''.join(str(e) for e in list_result)
      print(ranked_sentences[i][1])  
    df_sumary.append(list_result)
  except:
    list_result = ['']
    df_sumary.append(list_result)
# Out:
# Và nếu trong những điều các em nói có vài chuyện là đúng thì liệu giáo_viên có đủ dũng_cảm để thẳng_thắn thừa_nhận điều đó với các em không ?
# Nếu các em không hiểu lầm mà thực_sự ngỗ_ngược , hỗn_láo , thầy_cô và ban_giám_hiệu cần phân_tích , giải_thích để các em hiểu và thấy được lỗi của mình .
# Cùng với việc siết chặt về quy_mô , tính_chất hoạt_động , việc theo_dõi , xử_lý của các cơ_quan_chức_năng có thẩm_quyền thì các đơn_vị hoạt_động trong lĩnh_vực này phải tuân_thủ đúng theo các quy_định của pháp_luật để tránh xảy ra những biến_tướng , hậu_quả xấu đối_với xã_hội và chính đơn_vị có dịch_vụ đòi nợ thuê .
# Thứ nhất , ở góc_độ nhóm người đi đòi nợ thuê , đến nhà con_nợ và bị đánh thì buộc phải tôn_trọng vào các hoạt_động xác_minh , điều_tra của cơ_quan công_an .
# Cụ_thể , đó là nhóm ngành_nghề phải đảm_bảo về các điều_kiện an_ninh trật_tự , chứng_chỉ hành_nghề và yêu_cầu có vốn_pháp_định như : ngân_hàng , dịch_vụ đòi nợ , bất_động_sản , dịch_vụ bảo_vệ , dịch_vụ pháp_lý , dịch_vụ khám_chữa_bệnh , dịch_vụ kế_toán , dịch_vụ xông_hơi , dịch_vụ môi_giới bất_động_sản … Luật_sư Hướng cho_biết thêm , vì dịch_vụ đòi nợ thuê là hoạt_động kinh_doanh có điều_kiện nên phải tuân_thủ chặt_chẽ mọi quy_định của pháp_luật , chứ không được tuỳ_tiện đến nhà con_nợ để đòi nợ .
# Ying_Lin , 46 tuổi , bị_cáo buộc vận_chuyển những kiện hàng trên các chuyến bay từ sân_bay quốc_tế John_F._Kennedy tới Trung_Quốc , để đổi lấy những tặng_phẩm như thiết_bị điện_tử của Apple , rượu miễn thuế , các công_tố_viên cho_biết .
# Lin được cho là nhận kiện hàng từ các sĩ_quan quân_sự thuộc phái_đoàn Trung_Quốc ở Liên_Hợp_Quốc tại New_York và từ các nhân_viên khác thuộc lãnh_sự_quán Trung_Quốc ở thành_phố này .
# Lin sống tại khu_vực Queens , New_York , bị bắt hồi tháng 8/2015 vì một cáo_buộc khác .
# Đây là vấn_đề về việc bị ngăn_cản hoặc gây trở_ngại do các công_trình xây_dựng ở đó và chúng_tôi không_thể thực_thi tự_do các quyền theo Công_ước về Luật biển của Liên_Hợp_Quốc_UNCLOS đối_với vùng đặc_quyền kinh_tế 200 hải_lý của chúng_tôi " .
# Sẽ không_bao_giờ có chuyện chúng_tôi nhượng lại quyền của mình ở bãi cạn Scarborough " , Reuters dẫn lời ông Duterte nói tại một cuộc họp_báo sau khi hội_đàm với đại_sứ Trung_Quốc Zhang_Jianhua hôm_nay .
# Hồi giữa tháng trước , ông Duterte từng tuyên_bố muốn có quan_hệ thân_thiện với Trung_Quốc và sẵn_sàng đàm_phán trực_tiếp về tranh_chấp Biển_Đông .
# Mỗi câu_chuyện là một tình_huống khác nhau liên_quan đến việc chi_tiêu hằng_ngày trong cuộc_sống , gắn với những trải_nghiệm về thói_quen chi_tiêu tiền_mặt chuyển sang không dùng tiền_mặt , từ câu_chuyện bà ngoại thấp_thỏm chờ ông tiền điện đến thu , đến câu_chuyện đi mua_sắm ở Hàn_Quốc mà chưa ra đến chợ đã tiêu hết tiền ... Thay_đổi một thói_quen này phải bằng cách tạo ra một thói_quen khác , ở đây là thói_quen xài tiền_mặt sang các phương_tiện khác như thẻ , ví điện_tử , Internet banking ... Những người dùng thẻ ATM hẳn sẽ ngạc_nhiên khi cứ tưởng cái thẻ này chỉ có mỗi chức_năng là rút_tiền , nay thì không_những cà , quẹt mà_còn có_thể dùng được nhiều chuyện hay ho khác .
# Cụ_thể như bổ_sung hệ_thống dập cốc khô , hệ_thống các bể phòng sự_cố nước_thải , hệ_thống quan_trắc , mở hồ sinh_học , hồ điều_hoà … Đề_án dự_kiến triển_khai từ tháng 6/2016 và dự_kiến hoàn_thành cơ_bản trong quý I / 2017 ; một_vài hạng_mục lớn xong trong đầu năm 2019 .
# Theo giải_trình của Formosa , số vốn tăng lên là để đầu_tư vào Đề_án bảo_vệ môi_trường và cải_thiện sản_xuất , bao_gồm xây_dựng các hạng_mục bổ_sung theo chỉ_đạo của Bộ Tài_nguyên .
# Trước đó , để thể_hiện thiện_chí , Triều_Tiên đã trao_trả cho Mỹ ba tù_nhân và không tiến_hành thêm vụ thử hạt_nhân và tên_lửa nào trong năm 2018 .
# Tuy_nhiên , nhiều người Mỹ vẫn hoài_nghi_động_thái này và cho_rằng đó đơn_giản chỉ là dấu_hiệu cho thấy Bình_Nhưỡng đã hoàn_thiện chương_trình phát_triển vũ_khí_hạt_nhân .
# Những kẻ chỉ_trích , vốn cho rằng tôi sai_lầm ngay từ đầu , đã không còn gì để nói " , Tổng_thống Mỹ Donald_Trump hôm_nay đáp trả những chỉ_trích nhằm vào_cuộc gặp với lãnh_đạo Triều_Tiên trên tài_khoản Twitter cá_nhân .
# Hiện người_dân còn tự khai_thác đất mặt trên phần đất thuộc quyền sử_dụng của mình để bán làm vật_liệu san_lấp , không sử_dụng đất đúng mục_đích nông_nghiệp đang có chiều_hướng gia_tăng , lan rộng và rất phức_tạp .
# Tuy_nhiên , hàng năm 2 huyện Tri_Tôn , Tịnh_Biên vẫn còn xảy ra việc lấy đất mặt không phép để bán san_lấp mặt_bằng , xây_dựng nhà ở .
# Theo báo_cáo của UBND tỉnh An_Giang , gần 10 năm qua , cơ_quan_chức_năng tỉnh đã bắt và xử_lý trên 56 trường_hợp lấy đất mặt trái_phép ở 6 xã thuộc địa_bàn hai huyện Tri_Tôn và Tịnh_Biên , trong đó có một_số điểm Tuổi_Trẻ phản_ánh .
# Nhưng hành_vi giết người của Nguyễn_Xuân_Tiến là đặc_biệt nghiêm_trọng , hậu_quả làm 3 người chết và 4 người khác bị_thương trong điều_kiện Tiến hoàn_toàn bình_thường thì chiếu theo quy_định tại khoản 1 , Điều 123 , Bộ luật_hình_sự 2015 sửa_đổi năm 2017 , Nguyễn_Xuân_Tiến có_thể đối_mặt với mức án cao nhất của khung_hình_phạt nghiêm_khắc nhất là Tử_hình … ” Cũng theo Luật_sư Giáp , nếu trong trường_hợp Tiến được kết_luận giám_định tại thời_điểm gây án đang bị bệnh_tâm_thần hoặc một bệnh khác làm mất khả_năng nhận_thức , hoặc khả_năng điều_khiển hành_vi của mình thì không phải chịu trách_nhiệm hình_sự ( theo quy_định tại Điều 21 , Bộ luật_hình_sự 2015 sửa_đổi năm 2017 ) nhưng có_thể áp_dụng biện_pháp bắt_buộc chữa bệnh theo quy_định tại khoản 1 , Điều 49 , Bộ luật_hình_sự năm 2017 .
# Tại đây , sau khi gõ_cửa để ông B. ra mở_cửa , Tiến đã dùng dao chém ông B. bị_thương , sau đó tiếp_tục chém chết bà Trần_Thị_H.
# Ngoài_ra , trong trường_hợp kết_luận giám_định pháp_y xác_định Nguyễn_Xuân_Tiến khi gây án không bị mắc bệnh_tâm_thần , hoặc bệnh khác nhưng trước khi kết_án , hoặc khi thụ_án Nguyễn_Xuân_Tiến mắc bệnh_tâm_thần hoặc bệnh khác , thì cơ_quan có thẩm_quyền có_thể áp_dụng biện_pháp bắt_buộc chữa bệnh đối_với Tiến theo quy_định tại khoản 2 , khoản 3 Điều 49 Bộ luật_hình_sự 2015 sửa_đổi năm 2017 .
# Trong khi những ngành ngoài sư_phạm có mức điểm chuẩn dao_động từ 16-20 thì nhiều ngành sư_phạm của trường này có điểm chuẩn từ 22 đến trên 26 điểm .
# Riêng ngành y_tế công_cộng là ngành khó tuyển của trường trong nhiều năm nay có điểm 18,5 ( tăng 0,5 điểm , cũng là ngành có mức tăng thấp nhất của trường năm nay ) .
# Ngành có điểm chuẩn thấp nhất của trường cũng là ngành y_tế công_cộng 18 điểm ( tăng 1 điểm so với năm_ngoái ) .
# Nhận được thông_tin cần hỗ_trợ của tàu hàng , trung_tâm Phối_hợp tìm_kiếm cứu nạn Hàng_hải Khu_vực 3 đề_nghị hỗ_trợ thông_báo cho các tàu_thuyền khai_thác hải_sản trong khu_vực trên hỗ_trợ tìm_kiếm thuyền_viên mất_tích .
# Ngày 15/2 , tin từ ban Chỉ_huy phòng , chống thiên_tai và tìm_kiếm cứu nạn ( PCT T&T KCN ) tỉnh Cà_Mau cho biết , đơn_vị này có văn_bản gửi các ngành liên_quan hỗ_trợ tìm_kiếm thuyền_viên mất_tích trên biển .
# Khi tàu đang hành_trình đến toạ_độ 09001 ' N - 10400,1 ' E , cách Cà_Mau khoảng 47 hải_lý về phía Tây , mọi người phát_hiện một thuyền_viên không có trên tàu .
# Kênh_truyền_hình TV3 hôm_qua công_bố đoạn video lấy từ camera giám_sát cho thấy các nghi_phạm trong vụ án Kim_Jong - nam ba tháng trước từng gặp nhau tại một chung_cư , đồng_thời nêu nghi_vấn có_thể vụ sát_hại đã được lên kế_hoạch từ đây , theo China_Press .
# Đứng đợi ông có hai người đàn_ông mặc áo sẫm màu , cũng được cho là nghi_phạm trong vụ án .
# Cảnh_sát Malaysia đến nay đã xác_định có 4 nghi phạm Triều_Tiên là chủ_mưu , đồng_thời nghi_ngờ một bí_thư thứ_hai có dính_líu đến vụ giết người .
# Khi tới thời_điểm thích_hợp để hai nước thảo_luận về tranh_chấp , ông Duterte sẽ viện dẫn phán_quyết của Toà Trọng_tài ở The_Hague , Hà_Lan , trong đó vô_hiệu_hoá tuyên_bố chủ_quyền của Trung_Quốc với hầu_hết Biển_Đông .
# Không có liên_minh quân_sự , không gì cả , chỉ tìm_kiếm hoạt_động mậu_dịch và thương_mại " , Inquirer dẫn lời ông Rodrigo_Duterte hôm_qua nói với ông Shinzo_Abe về quan_hệ với Trung_Quốc . "
# Nhật hoan_nghênh nỗ_lực của Tổng_thống Duterte khi thăm Trung_Quốc và quyết_tâm tăng_cường , thúc_đẩy quan_hệ song_phương giữa Philippines và Trung_Quốc " , ông Abe nói .
# Ảnh : Thành_Trung " Cuốn sách không_chỉ điểm lại công_tác đối_ngoại của Việt_Nam trong năm 2015 , mà_còn nhìn lại cả hành_trình 5 năm vừa_qua , đồng_thời nêu bật những nội_dung cốt_yếu mới về đường_lối đối_ngoại của Đại_hội Đảng lần thứ XII " , Thứ_trưởng Ngoại_giao Lê_Hoài_Trung phát_biểu trong lễ công_bố sáng nay .
# Thứ_trưởng Trung cho biết đây là lần đầu_tiên Việt_Nam công_bố Sách xanh ngoại_giao , trong khi nhiều nước trên thế_giới hàng năm xuất_bản các ấn_phẩm tương_tự , được gọi là " Sách_Xanh ngoại_giao " ( Diplomatic_Bluebook ) hoặc Diplomatic_Whitebook , Greenbook , nhằm giới_thiệu về chính_sách đối_ngoại , những hoạt_động đối_ngoại nổi_bật .
# Bộ Ngoại_giao hy_vọng sẽ nhận được những ý_kiến đóng_góp để làm tốt hơn công_tác đối_ngoại , cũng như xuất_bản Sách_Xanh_Ngoại_giao Việt_Nam trong những năm tiếp_theo .
# Tiếp đó , ngày 15/10 , Bộ_trưởng Nguyễn_Văn_Thể tiếp_tục ký Văn_bản số 14587 / BGTVT - CQLXD gửi các đơn_vị có liên_quan về việc yêu_cầu VEC khẩn_trương sửa_chữa hư_hỏng mặt_đường bê_tông nhựa dự_án đường_cao_tốc Đà_Nẵng – Quảng_Ngãi .
# Một mặt , trong cuộc trao_đổi với Tiền_Phong , ông Tám vẫn kịp thanh_minh , tuyến đường xảy ra hư_hỏng đưa vào sử_dụng trước thời_điểm ông về làm Tổng_Giám_đốc .
# Về việc chậm sửa_chữa hư_hỏng , ông Tám lý_giải , việc sửa_chữa chỉ cần 2 ngày , nhưng thời_gian qua trời liên_tục mưa , nên ảnh_hưởng tới tiến_độ sửa_chữa tuyến đường .
# Nhựa là một vật_liệu phổ_biến trong cuộc_sống sinh_hoạt của con_người khắp thế_giới , nhưng chúng_ta hoàn_toàn có_thể thay_đổi tình_trạng rác_thải nhựa đại_dương bằng cách giảm sử_dụng vật_dụng làm từ nhựa .
# Các sinh_vật này sẽ chết vì không tiêu_hoá được hoặc nhanh_chóng trở_thành con mồi cho những loài lớn hơn .
# Nhựa không_chỉ trôi_nổi trên mặt_biển , làm ô_nhiễm không_khí và nguồn nước mà_còn bị các sinh_vật nuốt vào vì nhầm là thức_ăn .
# Theo lộ_trình tinh_giản biên_chế được trình , từ nay đến năm 2021 sẽ giảm từ 1,5 - 2 % biên_chế công_chức và số_lượng người làm_việc được giao .
# Trong vòng 3 năm kể từ ngày sáp_nhập , đơn_vị phải có giải_pháp sắp_xếp lại số cấp phó phù_hợp quy_định .
# Riêng khối sự_nghiệp , trên cơ_sở lượng người được trung_ương giao , UBND TP sẽ trình HĐND TP giảm 1,5 % .
# Nó có_thể thăm cảng tại Hàn_Quốc , theo Japan_Times .
# Sau khi đẻ rơi trên đường , mẹ con sản_phụ Nguyễn_Thị_Hằng được 2 thanh_niên cùng quê chở đến bệnh_viện , hiện sức_khoẻ bình_phục .
# Giang_Chinh   Sau khi đẻ rơi trên đường , mẹ con sản_phụ Nguyễn_Thị_Hằng được 2 thanh_niên cùng quê chở đến bệnh_viện , hiện sức_khoẻ bình_phục .
# Bà Văn_Thị_Thoa , mẹ chị Hằng kể , khi đi xe_máy đến_nơi , bà thấy con đã sinh , nằm sõng_soài dưới đất , còn chồng ủ ấm cho cháu bé .
# Trình_bày quan_điểm của nhóm nghiên_cứu dự_án luật , Phó chủ_nhiệm Uỷ_ban Tư_pháp Nguyễn_Công_Hồng khẳng_định trong thời_gian gấp như_vậy thì rất khó để có kết_quả nghiên_cứu đầy_đủ , ảnh_hưởng lớn đến chất_lượng chuẩn_bị báo_cáo về nội_dung dự_án luật , do_đó đề_nghị báo_cáo Uỷ_ban Thường_vụ_Quốc_hội trình Quốc_hội xem_xét , thông_qua tại 3 kỳ họp ( kéo_dài thêm một kỳ so với dự_kiến ) .
# Chủ_nhiệm Uỷ_ban Tư_pháp Lê_Thị_Nga khẳng_định đây là dự_án luật quan_trọng , từng được Quốc_hội_đồng_ý cho lùi lại một kỳ họp , nhưng đến tận chiều 23-8 cơ_quan thẩm_tra mới nhận được tài_liệu . "
# Cái chúng_tôi lo_ngại nhất là sau đây đồng_chí Lê_Quý_Vương chuyển lại dự_án luật này cho chúng_tôi để đi làm án .
# Không_thể nói rằng eo_biển Hormuz là nơi các bạn được tự_do qua_lại , trong khi eo_biển Gibraltar bị hạn_chế với chúng_tôi " , Rouhani nói , đề_cập đến việc thuỷ_quân_lục_chiến Anh bắt tàu chở dầu Grace 1 ngoài khơi vùng lãnh_thổ Gibraltar hồi tháng trước với cáo_buộc chở dầu cho Syria .
# Căng_thẳng giữa Iran với Mỹ và các nước phương Tây leo_thang kể từ khi Tổng_thống Mỹ Donald_Trump hồi năm_ngoái quyết_định rút khỏi Thoả_thuận hạt_nhân Iran 2015 ( JCOPA ) và áp các lệnh trừng_phạt lên quốc_gia Vùng_Vịnh này .
# Căng_thẳng không có dấu_hiệu hạ nhiệt khi Iran liên_tiếp bắt các tàu chở dầu nước_ngoài ở Vùng_Vịnh .
# Có_thể kể một_số như " Sinh_nhật của Mẹ " ( nói về Đảng Lao_động Triều_Tiên ) , " Chúng_ta gọi ông ấy là Cha " ( nói về ông Kim ) ... Nhóm Moranbong từng huỷ một buổi biểu_diễn ở Bắc_Kinh nhăm 2015 và trở_về nhà sau khi các quan_chức Trung_Quốc " thấy có vấn_đề " với việc ban tổ_chức treo những hình_ảnh tuyên_truyền trên sân_khấu mô_tả tên_lửa tầm_xa của Triều_Tiên .
# Trong cuộc hội_đàm giữa Triều_Tiên và Hàn_Quốc ngày 15-1 tại làng Bàn_Môn_Điếm ở khu_phi_quân_sự có một gương_mặt nữ từng xuất_hiện trên mặt báo : cô Hyon Song_Wol - trưởng nhóm nhạc nữ Moranbong của Triều_Tiên .
# Sau đây là 4 thông_tin thú_vị về cô mà báo_chí đã đăng_tải trong những năm qua .
# Cũng theo vị này , hiện Vietjet và Thái_Vietjet đang khai_thác hơn 70 máy_bay , trong đó đã nhận và khai_thác từ cuối năm 2014 đến nay 55 máy_bay trong đơn hàng lớn ký_kết với nhà_sản_xuất máy_bay Airbus .
# Sau 4 ngày công_bố ký hợp_đồng mua máy_bay , chiều 2-3 , Hãng Vietjet cho_biết theo kế_hoạch của đơn hàng này máy_bay sẽ được giao cho Vietjet từ nay đến năm 2025 .
# Đại_diện Bamboo_Airways cho_biết những chiếc máy_bay đầu_tiên sẽ được phía Boeing bàn_giao cho đối_tác Việt_Nam từ tháng 3-2020 .
# Bên cạnh đó , kinh_tế tăng_trưởng liên_tục , nhưng vẫn lo_lắng thiếu bền_vững là do khu_vực có vốn đầu_tư nước_ngoài ngày_càng tăng lên và đóng_góp nhiều vào tăng_trưởng của Việt_Nam .
# Đánh_giá thêm về nền kinh_tế của nước ta năm 2018 , ĐBQH Trần_Hoàng_Ngân cho rằng , đáng ghi_nhận là kinh_tế đã đạt kết_quả kép .
# Bên lề Quốc_hội , ĐBQH Trần_Hoàng_Ngân cũng đã có những chia_sẻ , đánh_giá của mình về nền kinh_tế cả nước trong năm 2018 .
# Nông_dân có mẫu cà_phê được giải sẽ được Công_ty UCC mua toàn_bộ sản_lượng trong vườn hiện có đưa về Nhật_Bản để giới_thiệu và quảng_bá về chất_lượng cà_phê Việt_Nam .
# Ông Vũ đã vượt qua 60 hộ nông_dân trồng cà_phê arabica được xem là những người trồng cà_phê chất_lượng cao tại Đà_Lạt để giành giải nhất .
# Khi mang ra thi , các mẫu cà_phê được xay tại_chỗ trước sự chứng_kiến của nông_dân , sau đó được các giám_khảo là chuyên_gia pha_chế cà_phê đến từ Nhật_Bản và Việt_Nam cảm_nhận mùi_vị từ khi mới xay cho đến khi được pha_chế thành thức uống .
# Phòng_ngủ của nạn_nhân sau vụ va_chạm .
# Vũ_Phong   Phòng_ngủ của nạn_nhân sau vụ va_chạm .
# Trong lúc chiếc trực_thăng của Không_quân Hoàng_gia Canada trở_lại căn_cứ của Mỹ ở bang Florida chiều 28/2 sau đợt huấn_luyện , một chiếc xuồng cứu_sinh lăn ra ngoài , rơi trúng mái nhà dân ở thành_phố Miami , theo National_Post .
# Iran đã triệu_tập các đại_sứ Đan_Mạch , Hà_Lan và tham_tán Anh để thông_báo về " sự phản_đối mạnh_mẽ " của Tehran đối_với việc các nước này " dung_túng " cho nhóm khủng_bố gây ra vụ xả súng tại lễ duyệt_binh ở thành_phố Ahvaz hôm_qua , IRNA đưa tin .
# Thật không_thể chấp_nhận việc Liên_minh châu_Âu không đưa các phần_tử khủng_bố này vào danh_sách đen chỉ vì chúng chưa phạm_tội tại châu_Âu " , phát_ngôn_viên Bộ Ngoại_giao Iran_Bahram_Qasemi cho biết , đề_cập tới Al - Ahvazi , nhóm phiến quân Hồi_giáo cũng nhận trách_nhiệm về vụ xả súng .
# Ông Trump , một người Cộng_hoà , thường công_khai lặp lại niềm_tin của mình rằng Bắc_Kinh đang cố_gắng làm chậm các cuộc đàm_phán thương_mại , với hi_vọng chiến_thắng của một ứng_cử_viên tổng_thống của Đảng Dân_chủ vào năm 2020 có_thể dẫn đến các điều_khoản tốt hơn trong một thoả_thuận với Mỹ .
# Trong loạt trạng_thái trên Twitter cá_nhân ngày 3-9 , ông Trump khẳng_định Mỹ đang làm rất tốt trong các cuộc đàm_phán thương_mại với Trung_Quốc , nhấn_mạnh các đòn thuế_quan của ông đang khiến nền kinh_tế Trung_Quốc gồng mình chịu_trận .
# Đương_kim tổng_thống Mỹ cảnh_báo Bắc_Kinh sẽ phải đối_mặt với các điều_khoản thương_mại cứng_rắn hơn trong nhiệm_kỳ hai của ông nếu cố_tình dây_dưa kéo_dài các cuộc đàm_phán . "
# Theo các nội_dung trong các Hợp_đồng góp vốn có yêu_cầu , trong mọi trường_hợp và vào bất_kỳ thời_điểm nào sau 6 tháng kể từ ngày HAGL Agrico ( HAGL Rubber ) thực_hiện niêm_yết ( ngày 10/7/2015 ) , Tập_đoàn có nghĩa_vụ mua lại toàn_bộ số cổ_phần HAGL Agrico mà FPT Capital nắm giữ trong trường_hợp ông Đoàn_Nguyên_Đức không thực_hiện cam_kết này .
# Ở phía ngược_lại , ông Đoàn_Nguyên_Đức phản_biện giá_trị 141 tỷ đồng của hơn 2,2 triệu cổ_phiếu HNG do FPT Capital yêu_cầu mua lại theo cách tính_toán của quỹ này là chưa hợp_lý .
# BCTC quý 1/2016 của FPT Capital thể_hiện , từ cuối 2015 đến 31/3/2016 , mục các khoản đầu_tư tài_chính dài_hạn đã không còn ghi_nhận nắm giữ cổ_phiếu HNG .
# Đoạn clip ghi lại hình_ảnh khoảng 1 phút và cộng_đồng mạng bức_xúc khi cho rằng tài_xế xe đầu kéo container xem thường pháp_luật , bất_chấp an_toàn tính_mạng của chính mình và người khác .
# HCM cho_biết đã làm_việc và xử_phạt vi_phạm hành_chính đối_với tài_xế Nguyễn_Hoàng_Khanh ( 37 tuổi ) - người vừa lái_xe đầu kéo container bằng chân vừa nghe điện_thoại .
# Cụ_thể , PC67 đã ra quyết_định xử_phạt lỗi ' dùng tay sử_dụng điện_thoại_di_động khi đang điều_khiển xe chạy trên đường ' và ' dùng chân điều_khiển vôlăng khi xe đang chạy trên đường ' theo nghị_định 46/2016/NĐ-CP của Chính_phủ .
# Hợp_tác quốc_phòng thực_chất , hiệu_quả Theo Bộ Ngoại_giao Việt_Nam , tại cuộc hội_đàm , nhằm đưa quan_hệ Đối_tác Chiến_lược vào thực_tiễn một_cách năng_động và thực_chất , hai bên cũng nhất_trí thiết_lập các cơ_chế tiếp_xúc ở cấp Bộ_trưởng Ngoại_giao , Quốc_phòng và các Bộ_trưởng phụ_trách kinh_tế , đồng_thời duy_trì các cơ_chế hợp_tác song_phương hiện có như Đối_thoại Chiến_lược Ngoại_giao và Quốc_phòng , Tham_vấn Lãnh_sự , đối_thoại về nông_nghiệp , giáo_dục , khoa_học - công_nghệ … ; tiếp_tục tích_cực triển_khai Chương_trình Hành_động Việt_Nam - Úc giai_đoạn 2016-2019 ; tạo điều_kiện cho các địa_phương hai nước đẩy_mạnh quan_hệ hợp_tác .
# Hai Thủ_tướng nhất_trí khuyến_khích các hãng hàng_không hai nước mở thêm đường_bay thẳng giữa các thành_phố lớn của hai nước , công_dân hai nước tích_cực tham_gia Chương_trình Lao_động Kỳ nghỉ ; Úc tiếp_tục hỗ_trợ Việt_Nam trong lĩnh_vực nông_nghiệp công_nghệ_cao và nông_nghiệp hữu_cơ trên tinh_thần quan_hệ Đối_tác Nông_nghiệp ; ủng_hộ việc triển_khai Chương_trình Đối_tác Đổi_mới Việt_Nam - Úc để hỗ_trợ Việt_Nam nâng_cao năng_lực công_nghệ , đổi_mới , sáng_tạo .
# Thủ_tướng Malcolm_Turnbull đánh_giá cao vai_trò của Việt_Nam trong việc đưa Hiệp_định Đối_tác toàn_diện và tiến_bộ xuyên Thái_Bình_Dương ( CPTPP ) đi đến hoàn_thiện , ký_kết vừa_qua tại Chile , đề_nghị hai bên tiếp_tục phối_hợp chặt_chẽ trong quá_trình phê_chuẩn và triển_khai thực_hiện Hiệp_định ; tin_tưởng Hiệp_định không_chỉ mang lại lợi_ích cho các nước thành_viên mà_còn sẽ mở_đường cho Hoa_Kỳ và các nước khác nếu muốn tham_gia sau_này .
# Tổng_thống Duterte " không có vấn_đề gì với những linh_mục muốn bảo_vệ giá_trị sinh_mạng " nhưng ông phải lựa_chọn " vì lợi_ích lớn nhất của số đông " .
# Ông cũng không hài_lòng khi đặt mua vũ_khí và đạn cho cảnh_sát , lực_lượng sẽ dùng chúng trong chiến_dịch chống ma_tuý .
# Nếu không diệt chúng thì chúng_ta sẽ ở trong tình_trạng tồi_tệ " , ông cho_biết . "
# Việc này chỉ giải_quyết được vấn_đề trước_mắt về đường giao_thông , bãi đỗ xe nhưng không xử_lý được vấn_đề chính là thoát nước , ô_nhiễm nước_thải và sẽ để lại nhiều hệ_luỵ cho quy_hoạch của thành_phố .
# Năm 2014 , Sở Tài_nguyên và Môi_trường phối_hợp với Công_ty Thoát nước Hà_Nội thả 38 cụm bè thuỷ_sinh từ đoạn Hoàng_Quốc_Việt đến Nguyễn_Trãi nhằm tạo cảnh_quan và cải_thiện chất_lượng nước sông Tô_Lịch .
# Tại phiên thảo_luận kinh_tế - xã_hội của HĐND TP Hà_Nội ngày 8/7 , Bí_thư quận Hoàn_Kiếm Dương_Đức_Tuấn đề_nghị thành_phố xem_xét cống_hoá với một_số sông có tính_chất kênh , mương thoát nước như Tô_Lịch , Kim_Ngưu vì cho_rằng sẽ góp_phần giảm_thiểu việc xả thải , tăng thêm không_gian công_cộng , cây_xanh và hạ_tầng giao_thông .
# Trong văn_bản của huyện An_Lão cũng nêu rõ yêu_cầu từ năm_học 2017-2018 , các khoản thu của Trường tiểu_học xã Tân_Dân và các trường công_lập khác thuộc huyện phải rà_soát , tổng_hợp và báo_cáo đầy_đủ về UBND huyện , thông_qua phòng tài_chính - kế_hoạch và Phòng giáo_dục - đào_tạo ; nghiêm_cấm thu các khoản không đúng theo quy_định .
# Riêng các tỉnh từ Quảng_Bình trở vào đến Quảng_Ngãi , trời nắng_nóng về trưa và chiều , nhiệt_độ cao nhất trên 35 .
# Từ đêm 1/9 tới 3/9 , Bắc_Bộ liên_tục mưa to do chịu ảnh_hưởng của rãnh áp_thấp nối với vùng xoáy thấp phát_triển từ mặt_đất lên tới độ cao 5.000 m .
# Thăm và chúc_mừng GS - TS Nguyễn_Thành_Xương , đoàn cũng đã trao_đổi về chương_trình nâng_cao chất_lượng nguồn nhân_lực theo yêu_cầu mới , trong đó nhấn_mạnh vị_trí , vai_trò quan_trọng của ngành giáo_dục với sự phát_triển của TP.
# Nếu khu_đô_thị Đại_học quốc_tế được thành_lập , có những điều_kiện tốt như nước_ngoài thì không ai đi du_học " - GS.TS Trần_Hồng_Quân chia_sẻ và đồng_tình với quan_điểm của thành_phố về khu_đô_thị Đại_học quốc_tế .
# HCM Nguyễn_Thành_Phong cho_biết TP rất muốn lắng_nghe những góp_ý , ý_kiến của đội_ngũ trí_thức là nhà_giáo lâu năm để xây_dựng TP.
# UBND TP Hà_Nội cũng yêu_cầu UBND các quận , huyện , thị_xã tăng_cường thanh_tra , kiểm_tra các khoản thu , chi trong các cơ_sở GD trên địa_bàn , xủ_lý nghiêm đối_với người đứng đầu cơ_sở GD và cơ_quan quản_lý GD trên địa_bàn nếu xảy ra tình_trạng lạm_thu .
# Nội_dung trên trong văn_bản số 1772 / UBND - KGVX về việc thực_hiện các khoản thu trong lĩnh_vực GD-ĐT do ông Ngô_Văn_Quý , phó chủ_tịch UBND TP Hà_Nội vừa kí .
# Phụ_huynh và giáo_viên ở Trường THPT Yên_Hoà - Hà Nội cùng bàn_bạc thống_nhất các hoạt_động hỗ_trợ học_sinh - ẢNH THU_THỦY
# Chương_trình trao_đổi hàng_hải Hàn_Quốc nằm trong số những chương_trình huấn_luyện đã bị ngừng lại vào tháng 6/2018 , sau khi Tổng_thống Mỹ Donald_Trump gặp lãnh_đạo Triều_Tiên_Kim_Jong-un ở Singapore và cam_kết dừng mọi hoạt_động tập_trận chung Mỹ - Hàn vốn bị Triều_Tiên chỉ_trích .
# The Washington_Post đã dẫn lời một_số quan_chức quân_đội giấu tên bày_tỏ lo_ngại rằng việc giảm hiện_diện quân_sự của Mỹ tại Trung_Đông đã giáng một đòn vào khả_năng phản_ứng của Mỹ đối_với các mối đe_doạ tiềm_tàng của Iran trong bối_cảnh cái mà họ gọi là khả_năng đối_đầu giữa hai nước đang gia_tăng do các biện_pháp trừng_phạt .
# Tờ_báo Thổ_Nhĩ_Kỳ Sabah dẫn nguồn tin giấu tên nói rằng thi_thể của nhà_báo Jamal_Khashoggi bị chia nhỏ và nhét vào 5 va_li sau khi ông bị siết cổ trong lãnh_sự_quán Saudi_Arabia tại Istanbul hôm 2/10 .
# Video được camera hành_trình của ôtô chạy vuông_góc với hướng đi của xe_tải ghi lại .
# Đức xác_định nghi_phạm là Anis_Amri , 24 tuổi , người gốc Tunisia và treo thưởng hơn 100.000 USD cho bất_kỳ ai cung_cấp thông_tin để bắt_giữ nghi_phạm .
# Khi ôtô này dừng đèn_đỏ , xe_tải tăng_tốc vượt qua các phương_tiện và lao thẳng vào khu chợ Giáng_sinh đang nhấp_nháy đèn với tốc_độ khoảng 64 km/h , theo Reuters .
# Về khai_thác dầu_khí , phấn_đấu cả năm khai_thác đạt tối_thiểu 13,28 triệu tấn dầu_thô và 10,61 tỷ m3 khí … Tiếp đó , các đồng_chí đại_diện lãnh_đạo PVN , các đơn_vị đã trình_bày các thuận_lợi , khó_khăn và khẳng_định thể_hiện sự quyết_tâm thực_hiện các mục_tiêu sản_xuất kinh_doanh mà Đảng , Chính_phủ giao ; đồng_thời mong_muốn sẽ tiếp_tục nhận được nhiều hơn_nữa sự quan_tâm , chỉ_đạo của Chính_phủ , của Thủ_tướng Chính_phủ và các Bộ ngành liên_quan trong việc tháo_gỡ những cơ_chế , vướng_mắc đối_với hoạt_động của Tập_đoàn .
# Báo_cáo đoàn công_tác của Thủ_tướng , Phó Bí_thư Phụ_trách Đảng_uỷ , Thành_viên phụ_trách Hội_đồng Thành_viên , Tổng_giám_đốc Nguyễn_Vũ_Trường_Sơn cho biết , được sự quan_tâm chỉ_đạo sâu_sát và dành những điều_kiện tốt nhất cho Tập_đoàn từ Chính_phủ , Thủ_tướng Chính_phủ và các Bộ , ngành , cùng với sự tập_trung chỉ_đạo điều_hành quyết_liệt của tập_thể Hội_đồng Thành_viên , Ban Tổng_giám_đốc và sự nỗ_lực quyết_tâm của toàn_thể cán_bộ công_nhân_viên Tập_đoàn , Tập_đoàn cơ_bản hoàn_thành các chỉ_tiêu , nhiệm_vụ kế_hoạch đề ra trong 7 tháng đầu năm 2017 .
# Cũng tại buổi làm_việc , các Phó Thủ_tướng Vương_Đình_Huệ , Trịnh_Định_Dũng và lãnh_đạo các Bộ , ngành Trung_ương đều ghi_nhận và đánh_giá cao những đóng_góp của PVN vào sự phát_triển chung của đất_nước cũng như những kết_quả mà PVN đạt được trong những năm gần đây và thể_hiện chia_sẻ với những khó_khăn của Tập_đoàn Dầu_khí Việt_Nam .
# Chúng_tôi tái khẳng_định tuyên_bố lên_án Nga sáp_nhập bất_hợp_pháp bán_đảo Crimea và tái khẳng_định chính_sách không công_nhận , trừng_phạt với các bên liên_quan " , Sputnik dẫn thông_cáo_chung của lãnh_đạo Nhóm các nước công_nghiệp phát_triển G7 phát hôm_nay tại Nhật .
# Các lãnh_đạo G7 cho_rằng xung_đột ở Ukraine chỉ có_thể được giải_quyết bằng các biện_pháp hoà_bình , tuân_thủ toàn_diện luật_quốc_tế , đặc_biệt là nghĩa_vụ pháp_lý trong việc tôn_trọng chủ_quyền , toàn_vẹn lãnh_thổ và độc_lập Ukraine .
# Liên_minh châu_Âu ( EU ) áp_đặt lệnh trừng_phạt với Nga vào tháng 7/2014 , sau vụ sáp_nhập Crimea và trong bối_cảnh xung_đột ở đông Ukraine .

# %%
len(df_sumary)
# Out:
# 22644

# %%
df = pd.DataFrame(df_sumary, columns = ['predict1', 'predict2','predict3'])

# %%
list_df = []
for i in range(len(df.predict1)):
  temp = str(df.predict1[i]) + str(df.predict2[i])+ str(df.predict3[i])
  list_df.append(temp)

# %%
temp = df.predict1[1] + df.predict2[1]+ df.predict3[1]
type(temp)
list_df.append(temp)

# %%
list_df = pd.DataFrame(list_df, columns = ['predict'])

# %%
list_df.head(5)
# Out:
#                                              predict
# 0  Thoả_thuận mới được ký_kết giữa Mỹ và Ấn_Độ ch...
# 1  Ban_Chấp_hành Trung_ương Đảng Nhân_dân Campuch...
# 2  Widodo nói ông muốn tuần_tra chung với Austral...
# 3  Cảnh_sát phòng cháy chữa_cháy phá tường , dẫn ...
# 4  Đoạn video do hành_khách quay lại cho thấy sự ...

# %%
df.head(5)
# Out:
#                                             predict1                                           predict2
# 0  Điều đáng nói , sức nóng phiên giao_dịch đầu_t...  Có_thể nói , EverGreen như bổ_sung thêm một đị...
# 1  Ông Nguyễn_Một : Mặc_dù nguyên_nhân sự_cố hỏng...  Do_đó , việc đặt ra vấn_đề “ làm gì để những s...
# 2  Quan_trọng là tất_cả các quốc_gia phải tôn_trọ...  Ngoài_ra , Ngoại_trưởng Australia cũng " hoan_...
# 3  Duterte hé lộ rằng Bắc_Kinh cảnh_báo ông " có_...  Trước kế_hoạch của ông Duterte , người_phát_ng...
# 4  Hai thanh_niên bị_thương điều_trị tại Viện Bỏn...  Tối 29/7 , Văn_phòng Chính_phủ có văn_bản truy...

# %%
bigdata = pd.concat([list_df.reset_index(drop=True), test_df.original.reset_index(drop=True)], axis=1)

# %%
bigdata = pd.concat([test_df['file'].reset_index(drop=True), bigdata.reset_index(drop=True)], axis=1)

# %%
bigdata.to_csv('test_predict.csv', encoding='utf-8')

# %% [markdown]
# # tính score

# %%
# !pip install -q rouge_score

# %%
bigdata.head()
# Out:
#                                                 file  ...                                           original
# 0  /content/vietnews-master/data/test_tokenized/0...  ...  Thoả_thuận mới được ký_kết giữa Mỹ và Ấn_Độ ch...
# 1  /content/vietnews-master/data/test_tokenized/0...  ...  Nguyên Tổng_bí_thư Đỗ_Mười . " Thay_mặt Đảng ,...
# 2  /content/vietnews-master/data/test_tokenized/0...  ...  Tổng_thống Indonesia_Widodo đứng trên boong ch...
# 3  /content/vietnews-master/data/test_tokenized/0...  ...  Cảnh_sát phun vòi rồng dập lửa . Video : Bá_Đô...
# 4  /content/vietnews-master/data/test_tokenized/0...  ...  Đồ_hoạ về vụ tai_nạn máy_bay Emirates . Đồ_hoạ...
#
# [5 rows x 3 columns]

# %%
from rouge_score import rouge_scorer
score_list = []
for i in range(len(bigdata.original)):
  scorer = rouge_scorer.RougeScorer(['rouge1','rouge2', 'rougeL'], use_stemmer=True)
  scores = scorer.score(str(bigdata.predict[i]),str(bigdata.original[i]))
  score_list.append(scores)

# %%
df_score_test = pd.DataFrame(score_list, columns = ['score'])

# %%
score_list[6]
# Out:
# {'rouge1': Score(precision=0.28837209302325584, recall=1.0, fmeasure=0.4476534296028881),
#  'rouge2': Score(precision=0.2867132867132867, recall=1.0, fmeasure=0.4456521739130435),
#  'rougeL': Score(precision=0.2441860465116279, recall=0.8467741935483871, fmeasure=0.3790613718411553)}

# %%
score_r1 = []
score_rl = []
score_r2 = []
for i in range(len(score_list)):
  score_r1.append(score_list[i]['rouge1'].fmeasure)
  score_r2.append(score_list[i]['rouge2'].fmeasure)
  score_rl.append(score_list[i]['rougeL'].fmeasure)

# %%
import statistics
print(statistics.mean(score_r1))
print(statistics.mean(score_r2))
print(statistics.mean(score_rl))
# Out:
# 0.45200444554247593
# 0.447521506032258
# 0.3774385023995794

# %% [markdown]
# - **2 câu**
# - R1: 0.34111518169308247
# - R2: 0.33769186213340274
# - RL: 0.3080631855000541
# - **3 câu**
#
#
# - R1: 0.45200444554247593
# - R2: 0.447521506032258
# - RL: 0.3774385023995794

# %% [markdown]
# # train set

# %%
import networkx as nx
df_train_sumary = []
# split the the text in the articles into sentences
sentences = []

for s in train_df.original:
  sentences.append(sent_tokenize(s))  
for i in range(len(train_df.original)):
  try:
    sentences_index = sentences[i]

    # remove punctuations, numbers and special characters
    clean_sentences = pd.Series(sentences_index).str.replace("[^\w\s]", " ")
    for i in range(len(clean_sentences)):
      clean_sentences[i] = " ".join(clean_sentences[i].split())
    clean_sentences = clean_sentences.replace('', np.nan).dropna()


    sentence_vectors = []
    for i in clean_sentences:
      if len(i) != 0:
        v = sum([embeddings_index.get(w, np.zeros((300,))) for w in i.split()])/(len(i.split())+0.001)
      else:
        v = np.zeros((300,))
      sentence_vectors.append(v)

    len(sentence_vectors)

    # similarity matrix
    sim_mat = np.zeros([len(sentences_index), len(sentences_index)])
    for i in range(len(sentence_vectors)):
      for j in range(len(sentence_vectors)):
        if i != j:
          sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,300), sentence_vectors[j].reshape(1,300))[0,0]



    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph)

    ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences_index)), reverse=True)

    # Specify number of sentences to form the summary
    sn = 1

    # Generate summary
    list_result = []
    str1 = []
    for i in range(sn):
      list_result.append(ranked_sentences[i][1])
      str1 = ''.join(str(e) for e in list_result)
      print(ranked_sentences[i][1])  
    df_sumary.append(list_result)
  except:
    list_result = ['']
    df_sumary.append(list_result)

# %%
df_train_pre = pd.DataFrame(df_train_sumary, columns = ['predict'])

# %%
bigdata_train = pd.concat([df_train_pre.reset_index(drop=True), train_df.original.reset_index(drop=True)], axis=1)

# %%
bigdata_train = pd.concat([train_df['file'].reset_index(drop=True), bigdata.reset_index(drop=True)], axis=1)

# %%
bigdata.to_csv('test_predict_1c.csv', encoding='utf8')

# %%
from rouge_score import rouge_scorer
score_list_train = []
for i in range(len(bigdata_train.original)):
  scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
  scores = scorer.score(bigdata_train.predict[i],bigdata_train.original[i])
  score_list_train.append(scores)

# %%
score_list_train

# %%
score_r1 = []
score_rl = []
for i in range(5000):
  score_r1.append(score_list_train[i]['rouge1'].fmeasure)
  score_rl.append(score_list_train[i]['rougeL'].fmeasure)

# %%
import statistics
print(statistics.mean(score_r1))
print(statistics.mean(score_rl))
# Out:
# 0.19911064978230728
# 0.19911064978230728

# %%
a = [1,2,3,4]
statistics.mean(a)
# Out:
# 2.5
